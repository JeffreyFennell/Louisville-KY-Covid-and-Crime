# %%
import pandas as pd
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# source: https://health.google.com/covid-19/open-data/explorer?loc=US_KY_21111
df= pd.read_csv('assets/US_KY_21111_edited.csv')
df.head()
# Out:
#          date country_code              country_name subregion1_code  \
# 0  2020-01-01           US  United States of America              KY
# 1  2020-01-02           US  United States of America              KY
# 2  2020-01-03           US  United States of America              KY
# 3  2020-01-04           US  United States of America              KY
# 4  2020-01-05           US  United States of America              KY
#
#   subregion1_name  subregion2_code   subregion2_name iso_3166_1_alpha_2  \
# 0        Kentucky            21111  Jefferson County                 US
# 1        Kentucky            21111  Jefferson County                 US
# 2        Kentucky            21111  Jefferson County                 US
# 3        Kentucky            21111  Jefferson County                 US
# 4        Kentucky            21111  Jefferson County                 US
#
#   iso_3166_1_alpha_3  aggregation_level  ...  search_trends_vaginitis  \
# 0                USA                  2  ...                     0.67
# 1                USA                  2  ...                     0.70
# 2                USA                  2  ...                     0.57
# 3                USA                  2  ...                     0.61
# 4                USA                  2  ...                     0.68
#
#    search_trends_varicose_veins  search_trends_vasculitis  \
# 0                          0.34                       NaN
# 1                          0.34                      0.14
# 2                          0.39                      0.21
# 3                          0.39                       NaN
# 4                          0.43                       NaN
#
#    search_trends_ventricular_tachycardia  search_trends_wheeze  \
# 0                                   0.16                  0.32
# 1                                   0.16                  0.30
# 2                                   0.25                  0.36
# 3                                   0.12                  0.25
# 4                                   0.16                  0.21
#
#    maximum_temperature_celsius  rainfall_mm  snowfall_mm  dew_point  \
# 0                     9.685185      0.00000          NaN  -2.708333
# 1                    11.228395      0.85725          NaN  -0.055556
# 2                    12.308642      9.55675          NaN  10.215278
# 3                    12.308642     10.19175          NaN   3.951389
# 4                     9.802469      0.92075          NaN  -1.937500
#
#    relative_humidity
# 0          59.746987
# 1          61.556646
# 2          94.049193
# 3          83.908394
# 4          69.816838
#
# [5 rows x 363 columns]

# %%
df.columns
# Out:
# Index(['date', 'country_code', 'country_name', 'subregion1_code',
#        'subregion1_name', 'subregion2_code', 'subregion2_name',
#        'iso_3166_1_alpha_2', 'iso_3166_1_alpha_3', 'aggregation_level',
#        ...
#        'search_trends_vaginitis', 'search_trends_varicose_veins',
#        'search_trends_vasculitis', 'search_trends_ventricular_tachycardia',
#        'search_trends_wheeze', 'maximum_temperature_celsius', 'rainfall_mm',
#        'snowfall_mm', 'dew_point', 'relative_humidity'],
#       dtype='object', length=363)
