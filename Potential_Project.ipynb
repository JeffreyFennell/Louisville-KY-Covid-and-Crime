# %%
import requests
import pandas as pd

# %% [markdown]
# ## Reference site for API
#
# #### https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4

# %%
# pull in the api data using the requests module and assign it to 'r'
# Using Covid 19 API
r = requests.get("https://data.cdc.gov/resource/n8mc-b4w4.json")

# determine the type of data I have.
r.headers['content-type']
# Out:
# 'application/json;charset=utf-8'

# %%
# I've determined that I have a json so let's pull it into a dataframe.
data= r.json()
# df= pd.DataFrame(data=data)
# df

# %%
# Create variable by refencing key you want to create df from.
raw_data = r.json()

# %%
# Create df using newly created variable
df= pd.DataFrame(data=raw_data)

# %%
df
# Out:
#     case_month res_state state_fips_code res_county county_fips_code  \
# 0      2022-06        PA              42     CARBON            42025
# 1      2020-11        PA              42    WYOMING            42131
# 2      2022-01        NH              33    BELKNAP            33001
# 3      2022-10        OH              39     WARREN            39165
# 4      2021-01        GA              13     OCONEE            13219
# ..         ...       ...             ...        ...              ...
# 995    2020-04        IA              19   MARSHALL            19127
# 996    2022-01        ID              16     CANYON            16027
# 997    2020-12        CO              08      DELTA            08029
# 998    2021-12        NJ              34      OCEAN            34029
# 999    2021-11        ID              16        ADA            16001
#
#           age_group     sex     race        ethnicity case_positive_specimen  \
# 0      0 - 17 years      NA       NA               NA                    0.0
# 1    50 to 64 years      NA       NA               NA                    0.0
# 2      0 - 17 years  Female       NA               NA                    0.0
# 3      0 - 17 years  Female       NA               NA                    0.0
# 4    18 to 49 years  Female       NA               NA                    NaN
# ..              ...     ...      ...              ...                    ...
# 995  50 to 64 years  Female  Missing  Hispanic/Latino                    NaN
# 996  18 to 49 years    Male  Missing  Hispanic/Latino                    0.0
# 997  18 to 49 years    Male  Missing  Hispanic/Latino                    NaN
# 998    0 - 17 years  Female    Black  Hispanic/Latino                    0.0
# 999    0 - 17 years  Female    White  Hispanic/Latino                    0.0
#
#     case_onset_interval              process exposure_yn  \
# 0                   0.0              Missing     Missing
# 1                   0.0              Missing     Missing
# 2                   0.0              Missing     Missing
# 3                   NaN              Missing     Missing
# 4                   0.0              Missing     Missing
# ..                  ...                  ...         ...
# 995                 0.0              Missing         Yes
# 996                 NaN  Laboratory reported     Missing
# 997                 NaN              Missing     Missing
# 998                 0.0              Missing     Missing
# 999                 NaN              Missing     Missing
#
#                 current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0    Laboratory-confirmed case    Symptomatic  Unknown  Unknown  Unknown
# 1    Laboratory-confirmed case    Symptomatic  Unknown  Unknown  Unknown
# 2    Laboratory-confirmed case    Symptomatic       No       No  Unknown
# 3                Probable Case        Missing  Missing  Missing  Unknown
# 4    Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# ..                         ...            ...      ...      ...      ...
# 995  Laboratory-confirmed case    Symptomatic       No       No       NA
# 996  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 997  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 998  Laboratory-confirmed case    Symptomatic      Yes  Missing       No
# 999  Laboratory-confirmed case        Unknown       No  Missing       No
#
#     underlying_conditions_yn
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 995                      NaN
# 996                      NaN
# 997                      NaN
# 998                      NaN
# 999                      NaN
#
# [1000 rows x 19 columns]

# %%
# df = df.drop(columns= ['FIPS', 'Admin2', 'Province_State', 'Recovered','Active'])

# %%
# df.reset_index(drop=True)
# Out:
#             Country_Region          Last_Update         Lat      Long_  \
# 0              Afghanistan  2023-03-10 04:21:03    33.93911  67.709953
# 1                  Albania  2023-03-10 04:21:03     41.1533    20.1683
# 2                  Algeria  2023-03-10 04:21:03     28.0339     1.6596
# 3                  Andorra  2023-03-10 04:21:03     42.5063     1.5218
# 4                   Angola  2023-03-10 04:21:03    -11.2027    17.8739
# ...                    ...                  ...         ...        ...
# 4011    West Bank and Gaza  2023-03-10 04:21:03     31.9522    35.2332
# 4012  Winter Olympics 2022  2023-03-10 04:21:03     39.9042   116.4074
# 4013                 Yemen  2023-03-10 04:21:03   15.552727  48.516388
# 4014                Zambia  2023-03-10 04:21:03  -13.133897  27.849332
# 4015              Zimbabwe  2023-03-10 04:21:03  -19.015438  29.154857
#
#      Confirmed Deaths          Combined_Key       Incident_Rate  \
# 0       209451   7896           Afghanistan   538.0424508714615
# 1       334457   3598               Albania   11621.96817012996
# 2       271496   6881               Algeria    619.132365905185
# 3        47890    165               Andorra   61981.49226687375
# 4       105288   1933                Angola  320.35277020195906
# ...        ...    ...                   ...                 ...
# 4011    703228   5708    West Bank and Gaza  13784.956960969268
# 4012       535      0  Winter Olympics 2022
# 4013     11945   2159                 Yemen   40.04899354817252
# 4014    343135   4057                Zambia   1866.491629984319
# 4015    264276   5671              Zimbabwe  1778.0885285919792
#
#       Case_Fatality_Ratio
# 0        3.76985547932452
# 1       1.075773567304616
# 2       2.534475646050034
# 3     0.34453956984756734
# 4       1.835916723653218
# ...                   ...
# 4011   0.8116855415313383
# 4012                  0.0
# 4013    18.07450816241105
# 4014   1.1823334839057513
# 4015   2.1458626587355645
#
# [4016 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   case_month                1000 non-null   object
#  1   res_state                 1000 non-null   object
#  2   state_fips_code           1000 non-null   object
#  3   res_county                1000 non-null   object
#  4   county_fips_code          1000 non-null   object
#  5   age_group                 1000 non-null   object
#  6   sex                       1000 non-null   object
#  7   race                      1000 non-null   object
#  8   ethnicity                 1000 non-null   object
#  9   case_positive_specimen    482 non-null    object
#  10  case_onset_interval       410 non-null    object
#  11  process                   1000 non-null   object
#  12  exposure_yn               1000 non-null   object
#  13  current_status            1000 non-null   object
#  14  symptom_status            1000 non-null   object
#  15  hosp_yn                   1000 non-null   object
#  16  icu_yn                    1000 non-null   object
#  17  death_yn                  1000 non-null   object
#  18  underlying_conditions_yn  34 non-null     object
# dtypes: object(19)
# memory usage: 148.6+ KB

# %%
df.describe()
# Out:
#        Country_Region          Last_Update   Lat Long_ Confirmed Deaths  \
# count            4016                 4016  4016  4016      4016   4016
# unique            201                   10  3925  3915      3770   1340
# top                US  2023-03-10 04:21:03                     0      0
# freq             3279                 4001    91    91        42    165
#
#        Combined_Key Incident_Rate Case_Fatality_Ratio
# count          4016          4016                4016
# unique         4016          3920                3807
# top     Afghanistan                               0.0
# freq              1            94                 131

# %%
df['Confirmed'] = df['Confirmed'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4016 entries, 0 to 4015
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country_Region       4016 non-null   object
#  1   Last_Update          4016 non-null   object
#  2   Lat                  4016 non-null   object
#  3   Long_                4016 non-null   object
#  4   Confirmed            4016 non-null   int64
#  5   Deaths               4016 non-null   object
#  6   Combined_Key         4016 non-null   object
#  7   Incident_Rate        4016 non-null   object
#  8   Case_Fatality_Ratio  4016 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 282.5+ KB

# %%
df['Confirmed'].sum()
# Out:
# 676570149

# %%
df['Confirmed'].mean().round(2)
# Out:
# 168468.66

# %%
data_check = df[df.Confirmed > df.Confirmed.mean()]
data_check
# Out:
#           Country_Region          Last_Update         Lat       Long_  \
# 0            Afghanistan  2023-03-10 04:21:03    33.93911   67.709953
# 1                Albania  2023-03-10 04:21:03     41.1533     20.1683
# 2                Algeria  2023-03-10 04:21:03     28.0339      1.6596
# 7              Argentina  2023-03-10 04:21:03    -38.4161    -63.6167
# 8                Armenia  2023-03-10 04:21:03     40.0691     45.0382
# ...                  ...                  ...         ...         ...
# 4009           Venezuela  2023-03-10 04:21:03      6.4238    -66.5897
# 4010             Vietnam  2023-03-10 04:21:03   14.058324  108.277199
# 4011  West Bank and Gaza  2023-03-10 04:21:03     31.9522     35.2332
# 4014              Zambia  2023-03-10 04:21:03  -13.133897   27.849332
# 4015            Zimbabwe  2023-03-10 04:21:03  -19.015438   29.154857
#
#       Confirmed  Deaths        Combined_Key       Incident_Rate  \
# 0        209451    7896         Afghanistan   538.0424508714615
# 1        334457    3598             Albania   11621.96817012996
# 2        271496    6881             Algeria    619.132365905185
# 7      10044957  130472           Argentina   22225.43269916568
# 8        447308    8727             Armenia  15095.264160710898
# ...         ...     ...                 ...                 ...
# 4009     552162    5854           Venezuela   1941.774886804352
# 4010   11526994   43186             Vietnam  11842.163348525424
# 4011     703228    5708  West Bank and Gaza  13784.956960969268
# 4014     343135    4057              Zambia   1866.491629984319
# 4015     264276    5671            Zimbabwe  1778.0885285919792
#
#      Case_Fatality_Ratio
# 0       3.76985547932452
# 1      1.075773567304616
# 2      2.534475646050034
# 7     1.2988806223859395
# 8     1.9510046768669462
# ...                  ...
# 4009  1.0601961018686545
# 4010  0.3746510148265888
# 4011  0.8116855415313383
# 4014  1.1823334839057513
# 4015  2.1458626587355645
#
# [522 rows x 9 columns]

# %%
# Print only 2nd and 3rd columns
only_2_cols = df.iloc[:, 1:3]
only_2_cols.head(5)
# Out:
#            Last_Update       Lat
# 0  2023-03-10 04:21:03  33.93911
# 1  2023-03-10 04:21:03   41.1533
# 2  2023-03-10 04:21:03   28.0339
# 3  2023-03-10 04:21:03   42.5063
# 4  2023-03-10 04:21:03  -11.2027

# %%
# Print first 4 rows
only_4_rows = df.iloc[:4]
only_4_rows.head(5)
# Out:
#   Country_Region          Last_Update       Lat      Long_  Confirmed Deaths  \
# 0    Afghanistan  2023-03-10 04:21:03  33.93911  67.709953     209451   7896
# 1        Albania  2023-03-10 04:21:03   41.1533    20.1683     334457   3598
# 2        Algeria  2023-03-10 04:21:03   28.0339     1.6596     271496   6881
# 3        Andorra  2023-03-10 04:21:03   42.5063     1.5218      47890    165
#
#   Combined_Key      Incident_Rate  Case_Fatality_Ratio
# 0  Afghanistan  538.0424508714615     3.76985547932452
# 1      Albania  11621.96817012996    1.075773567304616
# 2      Algeria   619.132365905185    2.534475646050034
# 3      Andorra  61981.49226687375  0.34453956984756734
