# %%
import requests
import pandas as pd 
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Reference site for API
#
# #### https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4

# %%
# pull in the api data using the requests module and assign it to 'r'
# Using Covid 19 API
r = requests.get("https://data.cdc.gov/resource/n8mc-b4w4.json")

# determine the type of data I have.
r.headers['content-type']
# Out:
# 'application/json;charset=utf-8'

# %%
# I've determined that I have a json so let's pull it into a dataframe.
data= r.json()
# df= pd.DataFrame(data=data)
# df

# %%
# Create variable by refencing key you want to create df from.
raw_data = r.json()

# %%
# Create df using newly created variable
df= pd.DataFrame(data=raw_data)

# %%
df
# Out:
#     case_month res_state state_fips_code    res_county county_fips_code  \
# 0      2022-08        TX              48        DENTON            48121
# 1      2022-01        FL              12    PALM BEACH            12099
# 2      2021-09        CA              06     SAN DIEGO            06073
# 3      2022-09        GA              13        FULTON            13121
# 4      2022-11        NJ              34         ESSEX            34013
# ..         ...       ...             ...           ...              ...
# 995    2023-02        NY              36          ERIE            36029
# 996    2021-04        PA              42         BUCKS            42017
# 997    2022-07        AZ              04      MARICOPA            04013
# 998    2021-01        CA              06     RIVERSIDE            06065
# 999    2021-11        MD              24  ANNE ARUNDEL            24003
#
#           age_group     sex     race            ethnicity  process  \
# 0      0 - 17 years  Female    Black  Non-Hispanic/Latino  Missing
# 1      0 - 17 years  Female    White  Non-Hispanic/Latino  Missing
# 2    50 to 64 years  Female    White  Non-Hispanic/Latino  Missing
# 3    50 to 64 years  Female  Missing              Missing  Missing
# 4    18 to 49 years    Male       NA                   NA  Missing
# ..              ...     ...      ...                  ...      ...
# 995       65+ years  Female  Missing              Unknown  Missing
# 996  50 to 64 years    Male    White  Non-Hispanic/Latino  Missing
# 997       65+ years    Male    White  Non-Hispanic/Latino  Missing
# 998  18 to 49 years    Male    White  Non-Hispanic/Latino  Missing
# 999  50 to 64 years    Male    White              Missing  Missing
#
#     exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0       Missing  Laboratory-confirmed case        Missing       No  Missing
# 1       Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 2       Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 3       Missing  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 4       Missing  Laboratory-confirmed case        Missing       No  Missing
# ..          ...                        ...            ...      ...      ...
# 995     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 996     Missing  Laboratory-confirmed case    Symptomatic  Unknown  Unknown
# 997     Missing              Probable Case        Missing  Missing  Missing
# 998     Missing              Probable Case   Asymptomatic       No  Missing
# 999     Missing  Laboratory-confirmed case    Symptomatic  Unknown  Missing
#
#     death_yn case_onset_interval case_positive_specimen  \
# 0         No                 NaN                    NaN
# 1    Missing                 NaN                    NaN
# 2    Missing                 0.0                    NaN
# 3    Missing                 0.0                    NaN
# 4         No                 NaN                    0.0
# ..       ...                 ...                    ...
# 995       No                 NaN                    NaN
# 996  Unknown                 0.0                    0.0
# 997  Missing                 NaN                    NaN
# 998  Missing                 NaN                    NaN
# 999       No                 0.0                    NaN
#
#     underlying_conditions_yn
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 995                      NaN
# 996                      NaN
# 997                      NaN
# 998                      NaN
# 999                      NaN
#
# [1000 rows x 19 columns]

# %%
# df = df.drop(columns= ['col1', 'col2'])

# %%
df.sort_values(by=['case_month', 'res_state'], inplace=True)

# %%
df

# %%
df.info()

# %%
df.describe()

# %%
df['Confirmed'] = df['Confirmed'].astype(int)

# %%
df.info()

# %%
df['Confirmed'].sum()

# %%
df['Confirmed'].mean().round(2)

# %%
data_check = df[df.Confirmed > df.Confirmed.mean()]
data_check

# %%
# Print only 2nd and 3rd columns
only_2_cols = df.iloc[:, 1:3]
only_2_cols.head(5)

# %%
# Print first 4 rows
only_4_rows = df.iloc[:4]
only_4_rows.head(5)
